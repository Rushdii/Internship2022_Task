# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
dataset = pd.read_csv(r"C:\Users\dell\Desktop\task\Data-science task\drinkMenu.csv")
dataset.columns = dataset.columns.str.replace(' ','_')
dataset
# Out:
#                     Beverage_category  \
# 0                              Coffee
# 1             Classic Espresso Drinks
# 2             Classic Espresso Drinks
# 3             Classic Espresso Drinks
# 4             Classic Espresso Drinks
# 5             Classic Espresso Drinks
# 6             Classic Espresso Drinks
# 7             Classic Espresso Drinks
# 8           Signature Espresso Drinks
# 9           Signature Espresso Drinks
# 10          Signature Espresso Drinks
# 11          Signature Espresso Drinks
# 12                   Tazo® Tea Drinks
# 13                   Tazo® Tea Drinks
# 14                   Tazo® Tea Drinks
# 15                   Tazo® Tea Drinks
# 16                   Tazo® Tea Drinks
# 17              Shaken Iced Beverages
# 18              Shaken Iced Beverages
# 19              Shaken Iced Beverages
# 20              Shaken Iced Beverages
# 21                          Smoothies
# 22                          Smoothies
# ...

# %%
dataset.drop_duplicates(subset=['Beverage_category','Beverage'])
# Out:
#                     Beverage_category  \
# 0                              Coffee
# 1             Classic Espresso Drinks
# 2             Classic Espresso Drinks
# 3             Classic Espresso Drinks
# 4             Classic Espresso Drinks
# 5             Classic Espresso Drinks
# 6             Classic Espresso Drinks
# 7             Classic Espresso Drinks
# 8           Signature Espresso Drinks
# 9           Signature Espresso Drinks
# 10          Signature Espresso Drinks
# 11          Signature Espresso Drinks
# 12                   Tazo® Tea Drinks
# 13                   Tazo® Tea Drinks
# 14                   Tazo® Tea Drinks
# 15                   Tazo® Tea Drinks
# 16                   Tazo® Tea Drinks
# 17              Shaken Iced Beverages
# 18              Shaken Iced Beverages
# 19              Shaken Iced Beverages
# 20              Shaken Iced Beverages
# 21                          Smoothies
# 22                          Smoothies
# ...

# %%
seaborn.set_style("whitegrid")
res = seaborn.barplot(x=dataset['Calories'],y=dataset['Beverage'],color='black',)
plt.gcf().set_size_inches(15,8)

# %%
dataset.columns = dataset.columns.str.replace(' ','_')
seaborn.set_style("whitegrid")
res = seaborn.barplot(x=dataset['_Sugars_(g)'],y=dataset['Beverage'],color='black',)
plt.gcf().set_size_inches(15,8)
